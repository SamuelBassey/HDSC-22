# %%
import numpy as np
import pandas as pd

# %%
FAO_df=pd.read_csv(r"C:\Users\USER\Desktop\FoodBalanceSheets_E_Africa.csv", encoding="latin-1")

# %%
FAO_df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
FAO_df.groupby("Item")["Y2015","Y2018"].sum()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12664\2383422703.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   FAO_df.groupby("Item")["Y2015","Y2018"].sum()
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
FAO_df.groupby("Element Code")["Y2014","Y2015","Y2016","Y2017","Y2018"].sum()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12664\3803006295.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   FAO_df.groupby("Element Code")["Y2014","Y2015","Y2016","Y2017","Y2018"].sum()
#                    Y2014       Y2015       Y2016       Y2017       Y2018
# Element Code
# 511           1031585.00  1058081.00  1085107.00  1112641.00  1140605.00
# 645             49650.63    49345.13    48985.28    48690.04    49056.85
# 664            454257.00   453383.00   451810.00   454681.00   455261.00
# 674             11836.46    11833.95    11779.69    11842.45    11833.56
# 684             10225.56    10235.74    10102.77    10253.84    10258.69
# 5072            58749.83    34910.99    33140.12    54316.91    20577.91
# 5123           153223.00   155439.00   157787.00   160614.00   163902.00
# 5131           282923.00   287929.00   280631.00   292836.00   308429.00
# ...

# %%
FAO_df.groupby("Item")["Y2015","Y2018"].max()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12664\3987900353.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   FAO_df.groupby("Item")["Y2015","Y2018"].max()
#                        Y2015    Y2018
# Item
# Alcohol, Non-Food      168.0    195.0
# Alcoholic Beverages   4885.0   4108.0
# Animal Products        483.0    494.0
# Animal fats          53546.0  51864.0
# Apples and products    972.0    910.0
# ...                      ...      ...
# Vegetables, Other    10992.0  11536.0
# Vegetal Products      3084.0   3077.0
# Wheat and products   19628.0  17683.0
# Wine                  1123.0    936.0
# Yams                 45678.0  50000.0
#
# [119 rows x 2 columns]

# %%
sum_of_processing=FAO_df.groupby("Element Code")["Y2017"].sum("Y2017")
print(sum_of_processing)
# Out:
# Element Code
# 511     1112641.00
# 645       48690.04
# 664      454681.00
# 674       11842.45
# 684       10253.84
# 5072      54316.91
# 5123     160614.00
# 5131     292836.00
# 5142    1258888.28
# 5154      91645.97
# 5170      35500.00
# 5171         91.00
# 5301    2088198.10
# 5511    2030056.89
# 5521     223705.68
# 5527      24870.14
# 5611     294559.09
# 5911     182338.80
# Name: Y2017, dtype: float64

# %%
FAO_df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
number_of_countries=FAO_df.groupby("Area")["Area","Y2017"].count()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12664\3955135640.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   FAO_df.groupby("Area")["Area","Y2017"].count()
#                              Area  Y2017
# Area
# Algeria                      1313   1279
# Angola                       1424   1407
# Benin                        1285   1253
# Botswana                     1378   1368
# Burkina Faso                 1409   1383
# Cabo Verde                   1260   1193
# Cameroon                     1460   1441
# Central African Republic     1344   1262
# Chad                         1343   1281
# Comoros                        45     45
# Congo                        1413   1395
# Côte d'Ivoire                1467   1454
# Djibouti                     1095   1061
# Egypt                        1488   1458
# Eswatini                     1284   1251
# Ethiopia                     1447   1428
# ...

# %%
FAO_df.groupby("Area")["Element"].sum()
# Out:
# Area
# Algeria                        Total Population - Both sexesDomestic supply q...
# Angola                         Total Population - Both sexesDomestic supply q...
# Benin                          Total Population - Both sexesDomestic supply q...
# Botswana                       Total Population - Both sexesDomestic supply q...
# Burkina Faso                   Total Population - Both sexesDomestic supply q...
# Cabo Verde                     Total Population - Both sexesDomestic supply q...
# Cameroon                       Total Population - Both sexesDomestic supply q...
# Central African Republic       Total Population - Both sexesDomestic supply q...
# Chad                           Total Population - Both sexesDomestic supply q...
# Comoros                        Import QuantityDomestic supply quantityOther u...
# Congo                          Total Population - Both sexesDomestic supply q...
# ...
